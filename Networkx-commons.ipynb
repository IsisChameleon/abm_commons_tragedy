# %%
import networkx as nx
import pyparsing
from pathlib import Path

# %%
# setup the path to the network files 
path=Path('/home/isischameleon/Dropbox/Coding/gitrepos/abm_commons_tragedy/networks')

# %%
# for windows users : use dir (or don't run)
# !ls -lt ./networks/*
# Out:
# -rw-rw-r-- 1 isischameleon isischameleon    4822 Jun  4 21:32 ./networks/network-gml-42161999.txt
# -rw-rw-r-- 1 isischameleon isischameleon   11189 Jun  4 21:32 ./networks/network-graphml-42161999.txt
# -rw-rw-r-- 1 isischameleon isischameleon   11189 Jun  4 21:32 ./networks/network-graphml-71406066.txt
# -rw-rw-r-- 1 isischameleon isischameleon    4821 Jun  4 21:32 ./networks/network-gml-71406066.txt
# -rw-rw-r-- 1 isischameleon isischameleon  316611 Jun  4 21:32 ./networks/network-graphml-46905590.txt
# -rw-rw-r-- 1 isischameleon isischameleon  237656 Jun  4 21:32 ./networks/network-gml-46905590.txt
# -rw-rw-r-- 1 isischameleon isischameleon  316633 Jun  4 21:32 ./networks/network-graphml-63206119.txt
# -rw-rw-r-- 1 isischameleon isischameleon  237682 Jun  4 21:32 ./networks/network-gml-63206119.txt
# -rw-rw-r-- 1 isischameleon isischameleon  316605 Jun  4 21:30 ./networks/network-graphml-29188402.txt
# -rw-rw-r-- 1 isischameleon isischameleon  237671 Jun  4 21:30 ./networks/network-gml-29188402.txt
# -rw-rw-r-- 1 isischameleon isischameleon  316605 Jun  4 21:30 ./networks/network-graphml-43270171.txt
# -rw-rw-r-- 1 isischameleon isischameleon  237678 Jun  4 21:30 ./networks/network-gml-43270171.txt
# -rw-rw-r-- 1 isischameleon isischameleon  316670 Jun  4 21:29 ./networks/network-graphml-73459513.txt
# -rw-rw-r-- 1 isischameleon isischameleon  237230 Jun  4 21:29 ./networks/network-gml-73459513.txt
# -rw-rw-r-- 1 isischameleon isischameleon  316709 Jun  4 20:36 ./networks/network-graphml-63089470.txt
# -rw-rw-r-- 1 isischameleon isischameleon  238340 Jun  4 20:36 ./networks/network-gml-63089470.txt
# -rw-rw-r-- 1 isischameleon isischameleon  316709 Jun  4 20:36 ./networks/network-graphml-45074086.txt
# -rw-rw-r-- 1 isischameleon isischameleon  238319 Jun  4 20:36 ./networks/network-gml-45074086.txt
# -rw-rw-r-- 1 isischameleon isischameleon 1011330 Jun  4 20:36 ./networks/network-graphml-68862909.txt
# -rw-rw-r-- 1 isischameleon isischameleon  768135 Jun  4 20:35 ./networks/network-gml-68862909.txt
# -rw-rw-r-- 1 isischameleon isischameleon  767033 Jun  4 20:20 ./networks/network-gml
# graph
# [
#   Creator Gephi
#   directed 0
#   node
#   [
#     id 704
#     label ""
#     graphics
#     [
#       x 287.71136
#       y -41.250946
#       z 0.0
#       w 1.0
#       h 1.0
#       d 1.0
#       fill "#e622"
#     ]
#     WHO "0.0"
#     COLOR "[230 2 2]"
#     HEADING "48.0"
#     XCOR "12.779890796744429"
#     YCOR "-9.788585828813922"
#     SHAPE "person"
#     LABEL-COLOR "9.9"
#     BREED "turtles"
#     HIDDEN? "false"
#     SIZE "1.0"
#     PEN-SIZE "1.0"
#     PEN-MODE "up"
#     TURTLE-VISION "8.0"
#     TURTLE-HUNGER "2.0"
#     TURTLE-HARVEST "5.0"
#     TURTLE-GROUP "(agentset, 2 turtles)"
#     TURTLE-RESOURCE "0.0"
#     TURTLE-WEALTH "0.0"
#     TURTLE-CURRENT-HARVEST "0.0"
#     CURRENT-ACTUAL-QUANTITY-HARVESTED "0.0"
#     CURRENT-HARVEST-RECOMMENDED-LEVEL "1.0"
#     TURTLE-TEST-HUB "2.0"
#     COMMUNITY "0.0"
#     NEW-PLACE "0.0"
#     MOVE-FRIEND "0.0"
#     MOVE-WITH-FRIEND-TICKER "0.0"
#     FIND-NEW-PLACE-TICKER "0.0"
#     TURTLE-HUNGER-LEVEL "0.0"
#     DEAD? "false"
#     HUNGRY? "false"
#     HUNGRY-FRIENDS-COUNT "0.0"
#     HFC-TICKER "0.0"
#     PRL-TICKER "0.0"
#     PRL-RESULT-TICKER "0.0"
#     PRL-RESULT-CURRENT-SITUATION "0.0"
#     CURRENT-PRL "0.0"
#     MAX-PRL "0.0"
#     RANDOM-VISIBLE-PATCH "0.0"
#     RANDOM-NEIGHBORING-PATCH "0.0"
#     RANDOM-VISIBLE-TURTLE "0.0"
#     BEST-VISIBLE-PATCH "0.0"
#     BEST-NEIGHBORING-PATCH "0.0"
#     BEST-VISIBLE-TURTLE "0.0"
#     TURTLE-MEMORY "{{table: [[311 [0]]]}}"
#     TURTLE-MEMORY-SIZE "5.0"
#     HAS-MOVED? "false"
#   ]
#   node
#   [
#     id 705
#     label ""
#     graphics
#     [
#       x -249.12875
#       y -211.55054
#       z 0.0
#       w 1.0
#       h 1.0
#       d 1.0
#       fill "#e622"
#     ]
#     WHO "1.0"
#     COLOR "[230 2 2]"
#     HEADING "104.0"
#     XCOR "10.931442661330504"
#     YCOR "3.915547381487233"
#     SHAPE "person"
#     LABEL-COLOR "9.9"
#     BREED "turtles"
#     HIDDEN? "false"
#     SIZE "1.0"
#     PEN-SIZE "1.0"
#     PEN-MODE "up"
#     TURTLE-VISION "8.0"
#     TURTLE-HUNGER "2.0"
#     TURTLE-HARVEST "5.0"
#     TURTLE-GROUP "(agentset, 1 turtle)"
#     TURTLE-RESOURCE "0.0"
#     TURTLE-WEALTH "0.0"
#     TURTLE-CURRENT-HARVEST "0.0"
#     CURRENT-ACTUAL-QUANTITY-HARVESTED "0.0"
#     CURRENT-HARVEST-RECOMMENDED-LEVEL "1.0"
#     TURTLE-TEST-HUB "1.0"
#     COMMUNITY "0.0"
#     NEW-PLACE "0.0"
#     MOVE-FRIEND "0.0"
#     MOVE-WITH-FRIEND-TICKER "0.0"
#     FIND-NEW-PLACE-TICKER "0.0"
#     TURTLE-HUNGER-LEVEL "0.0"
#     DEAD? "false"
#     HUNGRY? "false"
#     HUNGRY-FRIENDS-COUNT "0.0"
#     HFC-TICKER "0.0"
#     PRL-TICKER "0.0"
#     PRL-RESULT-TICKER "0.0"
#     PRL-RESULT-CURRENT-SITUATION "0.0"
#     CURRENT-PRL "0.0"
#     MAX-PRL "0.0"
#     RANDOM-VISIBLE-PATCH "0.0"
#     RANDOM-NEIGHBORING-PATCH "0.0"
#     RANDOM-VISIBLE-TURTLE "0.0"
#     BEST-VISIBLE-PATCH "0.0"
#     BEST-NEIGHBORING-PATCH "0.0"
#     BEST-VISIBLE-TURTLE "0.0"
#     TURTLE-MEMORY "{{table: [[631 [2]]]}}"
#     TURTLE-MEMORY-SIZE "5.0"
#     HAS-MOVED? "false"
#   ]
#   node
#   [
#     id 706
#     label ""
#     graphics
#     [
#       x 285.68237
#       y -216.71219
#       z 0.0
#       w 1.0
#       h 1.0
#       d 1.0
#       fill "#e622"
#     ]
#     WHO "2.0"
#     COLOR "[230 2 2]"
#     HEADING "315.0"
#     XCOR "-13.807266099873734"
#     YCOR "12.501818276939023"
#     SHAPE "person"
#     LABEL-COLOR "9.9"
#     BREED "turtles"
#     HIDDEN? "false"
#     SIZE "1.0"
#     PEN-SIZE "1.0"
#     PEN-MODE "up"
#     TURTLE-VISION "8.0"
#     TURTLE-HUNGER "2.0"
#     TURTLE-HARVEST "5.0"
#     TURTLE-GROUP "(agentset, 1 turtle)"
#     TURTLE-RESOURCE "0.0"
#     TURTLE-WEALTH "0.0"
#     TURTLE-CURRENT-HARVEST "0.0"
#     CURRENT-ACTUAL-QUANTITY-HARVESTED "0.0"
#     CURRENT-HARVEST-RECOMMENDED-LEVEL "1.0"
#     TURTLE-TEST-HUB "1.0"
#     COMMUNITY "0.0"
#     NEW-PLACE "0.0"
#     MOVE-FRIEND "0.0"
#     MOVE-WITH-FRIEND-TICKER "0.0"
#     FIND-NEW-PLACE-TICKER "0.0"
#     TURTLE-HUNGER-LEVEL "0.0"
#     DEAD? "false"
#     HUNGRY? "false"
#     HUNGRY-FRIENDS-COUNT "0.0"
#     HFC-TICKER "0.0"
#     PRL-TICKER "0.0"
#     PRL-RESULT-TICKER "0.0"
#     PRL-RESULT-CURRENT-SITUATION "0.0"
#     CURRENT-PRL "0.0"
#     MAX-PRL "0.0"
#     RANDOM-VISIBLE-PATCH "0.0"
#     RANDOM-NEIGHBORING-PATCH "0.0"
#     RANDOM-VISIBLE-TURTLE "0.0"
#     BEST-VISIBLE-PATCH "0.0"
#     BEST-NEIGHBORING-PATCH "0.0"
#     BEST-VISIBLE-TURTLE "0.0"
#     TURTLE-MEMORY "{{table: [[790 [5]]]}}"
#     TURTLE-MEMORY-SIZE "5.0"
#     HAS-MOVED? "false"
#   ]
#   edge
#   [
#     id 698
#     source 704
#     target 705
#     label ""
#     value 1.0
#     Label ""
#     END1 "(turtle 0)"
#     END2 "(turtle 1)"
#     COLOR "5.0"
#     LABEL-COLOR "9.9"
#     HIDDEN? "false"
#     BREED "links"
#     THICKNESS "0.0"
#     SHAPE "default"
#     TIE-MODE "none"
#     STRENGTH "7.717250103510553"
#   ]
#   edge
#   [
#     id 699
#     source 706
#     target 704
#     label ""
#     value 1.0
#     Label ""
#     END1 "(turtle 2)"
#     END2 "(turtle 0)"
#     COLOR "5.0"
#     LABEL-COLOR "9.9"
#     HIDDEN? "false"
#     BREED "links"
#     THICKNESS "0.0"
#     SHAPE "default"
#     TIE-MODE "none"
#     STRENGTH "5.954239208441908"
#   ]
# ]

# %%
# !cat ./networks/network-gml-42161999.txt
# Out:
# graph
# [
#   Creator Gephi
#   directed 0
#   node
#   [
#     id 704
#     label ""
#     graphics
#     [
#       x 287.71136
#       y -41.250946
#       z 0.0
#       w 1.0
#       h 1.0
#       d 1.0
#       fill "#e622"
#     ]
#     WHO "0.0"
#     COLOR "[230 2 2]"
#     HEADING "48.0"
#     XCOR "12.779890796744429"
#     YCOR "-9.788585828813922"
#     SHAPE "person"
#     LABEL-COLOR "9.9"
#     BREED "turtles"
#     HIDDEN? "false"
#     SIZE "1.0"
#     PEN-SIZE "1.0"
#     PEN-MODE "up"
#     TURTLE-VISION "8.0"
#     TURTLE-HUNGER "2.0"
#     TURTLE-HARVEST "5.0"
#     TURTLE-GROUP "(agentset, 2 turtles)"
#     TURTLE-RESOURCE "0.0"
#     TURTLE-WEALTH "0.0"
#     TURTLE-CURRENT-HARVEST "0.0"
#     CURRENT-ACTUAL-QUANTITY-HARVESTED "0.0"
#     CURRENT-HARVEST-RECOMMENDED-LEVEL "1.0"
#     TURTLE-TEST-HUB "2.0"
#     COMMUNITY "0.0"
#     NEW-PLACE "0.0"
#     MOVE-FRIEND "0.0"
#     MOVE-WITH-FRIEND-TICKER "0.0"
#     FIND-NEW-PLACE-TICKER "0.0"
#     TURTLE-HUNGER-LEVEL "0.0"
#     DEAD? "false"
#     HUNGRY? "false"
#     HUNGRY-FRIENDS-COUNT "0.0"
#     HFC-TICKER "0.0"
#     PRL-TICKER "0.0"
#     PRL-RESULT-TICKER "0.0"
#     PRL-RESULT-CURRENT-SITUATION "0.0"
#     CURRENT-PRL "0.0"
#     MAX-PRL "0.0"
#     RANDOM-VISIBLE-PATCH "0.0"
#     RANDOM-NEIGHBORING-PATCH "0.0"
#     RANDOM-VISIBLE-TURTLE "0.0"
#     BEST-VISIBLE-PATCH "0.0"
#     BEST-NEIGHBORING-PATCH "0.0"
#     BEST-VISIBLE-TURTLE "0.0"
#     TURTLE-MEMORY "{{table: [[311 [0]]]}}"
#     TURTLE-MEMORY-SIZE "5.0"
#     HAS-MOVED? "false"
#   ]
#   node
#   [
#     id 705
#     label ""
#     graphics
#     [
#       x -249.12875
#       y -211.55054
#       z 0.0
#       w 1.0
#       h 1.0
#       d 1.0
#       fill "#e622"
#     ]
#     WHO "1.0"
#     COLOR "[230 2 2]"
#     HEADING "104.0"
#     XCOR "10.931442661330504"
#     YCOR "3.915547381487233"
#     SHAPE "person"
#     LABEL-COLOR "9.9"
#     BREED "turtles"
#     HIDDEN? "false"
#     SIZE "1.0"
#     PEN-SIZE "1.0"
#     PEN-MODE "up"
#     TURTLE-VISION "8.0"
#     TURTLE-HUNGER "2.0"
#     TURTLE-HARVEST "5.0"
#     TURTLE-GROUP "(agentset, 1 turtle)"
#     TURTLE-RESOURCE "0.0"
#     TURTLE-WEALTH "0.0"
#     TURTLE-CURRENT-HARVEST "0.0"
#     CURRENT-ACTUAL-QUANTITY-HARVESTED "0.0"
#     CURRENT-HARVEST-RECOMMENDED-LEVEL "1.0"
#     TURTLE-TEST-HUB "1.0"
#     COMMUNITY "0.0"
#     NEW-PLACE "0.0"
#     MOVE-FRIEND "0.0"
#     MOVE-WITH-FRIEND-TICKER "0.0"
#     FIND-NEW-PLACE-TICKER "0.0"
#     TURTLE-HUNGER-LEVEL "0.0"
#     DEAD? "false"
#     HUNGRY? "false"
#     HUNGRY-FRIENDS-COUNT "0.0"
#     HFC-TICKER "0.0"
#     PRL-TICKER "0.0"
#     PRL-RESULT-TICKER "0.0"
#     PRL-RESULT-CURRENT-SITUATION "0.0"
#     CURRENT-PRL "0.0"
#     MAX-PRL "0.0"
#     RANDOM-VISIBLE-PATCH "0.0"
#     RANDOM-NEIGHBORING-PATCH "0.0"
#     RANDOM-VISIBLE-TURTLE "0.0"
#     BEST-VISIBLE-PATCH "0.0"
#     BEST-NEIGHBORING-PATCH "0.0"
#     BEST-VISIBLE-TURTLE "0.0"
#     TURTLE-MEMORY "{{table: [[631 [2]]]}}"
#     TURTLE-MEMORY-SIZE "5.0"
#     HAS-MOVED? "false"
#   ]
#   node
#   [
#     id 706
#     label ""
#     graphics
#     [
#       x 285.68237
#       y -216.71219
#       z 0.0
#       w 1.0
#       h 1.0
#       d 1.0
#       fill "#e622"
#     ]
#     WHO "2.0"
#     COLOR "[230 2 2]"
#     HEADING "315.0"
#     XCOR "-13.807266099873734"
#     YCOR "12.501818276939023"
#     SHAPE "person"
#     LABEL-COLOR "9.9"
#     BREED "turtles"
#     HIDDEN? "false"
#     SIZE "1.0"
#     PEN-SIZE "1.0"
#     PEN-MODE "up"
#     TURTLE-VISION "8.0"
#     TURTLE-HUNGER "2.0"
#     TURTLE-HARVEST "5.0"
#     TURTLE-GROUP "(agentset, 1 turtle)"
#     TURTLE-RESOURCE "0.0"
#     TURTLE-WEALTH "0.0"
#     TURTLE-CURRENT-HARVEST "0.0"
#     CURRENT-ACTUAL-QUANTITY-HARVESTED "0.0"
#     CURRENT-HARVEST-RECOMMENDED-LEVEL "1.0"
#     TURTLE-TEST-HUB "1.0"
#     COMMUNITY "0.0"
#     NEW-PLACE "0.0"
#     MOVE-FRIEND "0.0"
#     MOVE-WITH-FRIEND-TICKER "0.0"
#     FIND-NEW-PLACE-TICKER "0.0"
#     TURTLE-HUNGER-LEVEL "0.0"
#     DEAD? "false"
#     HUNGRY? "false"
#     HUNGRY-FRIENDS-COUNT "0.0"
#     HFC-TICKER "0.0"
#     PRL-TICKER "0.0"
#     PRL-RESULT-TICKER "0.0"
#     PRL-RESULT-CURRENT-SITUATION "0.0"
#     CURRENT-PRL "0.0"
#     MAX-PRL "0.0"
#     RANDOM-VISIBLE-PATCH "0.0"
#     RANDOM-NEIGHBORING-PATCH "0.0"
#     RANDOM-VISIBLE-TURTLE "0.0"
#     BEST-VISIBLE-PATCH "0.0"
#     BEST-NEIGHBORING-PATCH "0.0"
#     BEST-VISIBLE-TURTLE "0.0"
#     TURTLE-MEMORY "{{table: [[790 [5]]]}}"
#     TURTLE-MEMORY-SIZE "5.0"
#     HAS-MOVED? "false"
#   ]
#   edge
#   [
#     id 698
#     source 704
#     target 705
#     label ""
#     value 1.0
#     Label ""
#     END1 "(turtle 0)"
#     END2 "(turtle 1)"
#     COLOR "5.0"
#     LABEL-COLOR "9.9"
#     HIDDEN? "false"
#     BREED "links"
#     THICKNESS "0.0"
#     SHAPE "default"
#     TIE-MODE "none"
#     STRENGTH "7.717250103510553"
#   ]
#   edge
#   [
#     id 699
#     source 706
#     target 704
#     label ""
#     value 1.0
#     Label ""
#     END1 "(turtle 2)"
#     END2 "(turtle 0)"
#     COLOR "5.0"
#     LABEL-COLOR "9.9"
#     HIDDEN? "false"
#     BREED "links"
#     THICKNESS "0.0"
#     SHAPE "default"
#     TIE-MODE "none"
#     STRENGTH "5.954239208441908"
#   ]
# ]

# %%
G=nx.read_gml(path/'network-gml-42161999.txt')

# %%
nx.draw_networkx(G)
